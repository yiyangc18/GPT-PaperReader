# %%
# 已处理的文献序号集合
processed_sets = [
    {114, 93, 3, 6, 12, 19, 25, 26, 28, 37, 56, 59, 60, 65, 66, 68, 71, 82,
     84, 88, 92, 94, 100, 103, 106, 113, 117, 125, 132, 133, 134, 137, 142, 151, 153, 158, 160,
     177, 178, 179, 184, 191, 209, 220, 227, 229, 231, 233, 241, 247, 259, 263, 265, 267, 272, 279,
     292, 300, 322, 323, 327, 331, 338, 345, 349, 352, 355, 356, 357, 359, 368, 370, 373, 387, 398, 407},
    {37, 68, 102, 160, 184, 227, 229, 298, 341, 409, 413, 415, 419, 478, 490, 493, 494, 501, 504,
     513, 536, 541, 546, 551, 555, 567, 572, 596, 600, 623, 627, 629, 632},
    {7, 14, 21, 40, 43, 48, 51, 53, 61, 76, 83, 122, 124, 131, 143, 149, 150, 156, 161, 182, 192,
     195, 207, 222, 223, 240, 250, 251, 271, 294, 297, 304, 305, 310, 313, 319, 339, 362, 377, 383, 
     389, 397, 399},
    {334, 337, 405, 483, 511, 518, 540, 558, 570, 581, 582, 590, 603, 637, 638, 643},
    {57, 33, 72, 85, 111, 140, 141, 146, 175, 196, 216, 217, 221, 264, 273, 340, 353, 403, 486, 500,
     506, 575, 636}
]

# 计算所有集合的并集
union_set = set().union(*processed_sets)

# 输出并集的排序列表
union_sorted = sorted(list(union_set))
len(union_sorted)
# Out:
# 185

# %%
'''
帮助我做一个文献分类任务。接下来我会依次给你一些文章的信息，你需要告诉我它们所解决的问题和使用的具体RL算法。
解决的问题是以下几个选择中的一个：['Lateral Control','Longitudinal Control','Longitudinal and Lateral Control','Path Planning','end-to-end']
使用的RL算法是以下中的一个或两个: ['DQN','DDPG','PPO','A3C','SAC','Actor-Critic','PG']
你的回答应该python能够解析的dict格式，key是文章的DIO，value是一个dict，包含两个key，一个是problem，一个是algorithm。例如：
'10.3103/S1060992X19040118': {'problem': 'Path Planning', 'algorithm': 'SAC'}
只需要回答processed_sets中的文章，不需要回答其他文章，不要回答做多余的回答。
如果你不知道某篇文章的问题或者算法，可以回答'Unknown'。
现在，如果你准备好了，请向我发送: 'i am ready'

'''

# %%
paper_method_domain_info ={
    '10.3103/S1060992X19040118': {'problem': 'Path Planning', 'algorithm': 'SAC'},
    '10.3390/app10165722': {
        'problem': 'Path Planning',
        'algorithm': 'PPO'
    },
    '10.1016/j.jfranklin.2022.06.052': {
        'problem': 'Path Planning',
        'algorithm': 'TD3'
    },
    '10.1080/15472450.2022.2046472': {
        'problem': 'Path Planning',
        'algorithm': 'DQN'
    },
        '10.1109/itsc45102.2020.9294275': {
        'problem': 'Path Planning',
        'algorithm': 'DDPG'
    },
    '10.1109/ISQED57927.2023.10129362': {
        'problem': 'Path Planning',
        'algorithm': 'DQN'
    },
    '10.1109/CIEEC58067.2023.10167001': {
        'problem': 'Path Planning',
        'algorithm': 'TD3'
    },
    '10.3390/electronics11152346': {
        'problem': 'Path Planning',
        'algorithm': 'TD3'
    },
    '10.1016/j.epsr.2020.106962': {
        'problem': 'Path Planning',
        'algorithm': 'DQN'
    },
    '10.1109/ACCESS.2020.3031037': {
        'problem': 'Path Planning',
        'algorithm': 'TD3'
    },
    '10.1109/IROS51168.2021.9635935': {
        'problem': 'Path Planning',
        'algorithm': 'Actor Critic'
    },
        '10.1007/s13042-023-01845-2': {
        'problem': 'Path Planning',
        'algorithm': 'SAC'
    },
    '10.1007/s12008-020-00717-1': {
        'problem': 'Path Planning',
        'algorithm': 'PPO'
    },
    '10.1109/LRA.2022.3192770': {
        'problem': 'Path Planning',
        'algorithm': 'PPO'
    },
    '10.5220/0007955504220429': {
        'problem': 'Path Planning',
        'algorithm': 'DDPG'
    },
    '10.23919/ecc51009.2020.9143675': {
        'problem': 'Path Planning',
        'algorithm': 'DDPG'
    },
    '10.3390/math11010132': {
        'problem': 'Path Planning',
        'algorithm': 'DDPG'
    },
    '10.3390/app131810056': {
        'problem': 'Path Planning',
        'algorithm': 'DQN'
    },
    '10.1109/ACSOS58161.2023.00030': {
        'problem': 'Path Planning',
        'algorithm': 'DDPG'
    },
    '10.1016/j.aei.2022.101754': {
        'problem': 'Path Planning',
        'algorithm': 'SAC'
    },
    '10.1007/s11042-021-11437-3': {
        'problem': 'Lateral Control',
        'algorithm': 'DDPG'
    },
    '10.1109/TITS.2019.2895285': {
        'problem': 'Lateral Control',
        'algorithm': 'DQN'
    },
    '10.3390/sym14010031': {
        'problem': 'Lateral Control',
        'algorithm': 'Actor Critic'
    },
    '10.1109/TITS.2023.3250720': {
        'problem': 'Lateral Control',
        'algorithm': 'Actor Critic'
    },
    '10.23919/ASCC56756.2022.9828057': {
        'problem': 'Lateral Control',
        'algorithm': 'PPO'
    },
    '10.3390/s22207881': {
        'problem': 'Lateral Control',
        'algorithm': 'DDPG'
    },
    '10.3390/s21144827': {
        'problem': 'Lateral Control',
        'algorithm': 'DDPG'
    },
    '10.3390/app10207171': {
        'problem': 'Lateral Control',
        'algorithm': 'PG'
    },
    '10.3390/ijerph20010893': {
        'problem': 'Longitudinal Control',
        'algorithm': 'DDPG'
    },
    '10.1109/LRA.2020.3012128': {
        'problem': 'Longitudinal Control',
        'algorithm': 'Model-based DDPG'
    },
    '10.1109/LRA.2020.3012128': {
        'problem': 'Longitudinal Control',
        'algorithm': 'Model-based DRL'
    },
    '10.5220/0010256208740881': {
        'problem': 'Longitudinal Control',
        'algorithm': 'DDPG'
    },
    '10.23919/ACC50511.2021.9483388': {
        'problem': 'Longitudinal Control',
        'algorithm': 'ADP'
    },
    '10.1109/TIV.2022.3233592': {
        'problem': 'Longitudinal and Lateral Control',
        'algorithm': 'Model-based DRL'
    },
    '10.1109/TVT.2022.3150793': {
        'problem': 'Longitudinal and Lateral Control',
        'algorithm': 'PG'
    },
    '10.1109/DDCLS58216.2023.10166569': {
        'problem': 'Longitudinal and Lateral Control',
        'algorithm': 'DDPG'
    },
    '10.1109/TITS.2023.3271642': {'problem': 'End to End', 'algorithm': 'Actor Critic'},
    '10.1109/LRA.2020.2966414': {'problem': 'End to End', 'algorithm': 'PG'},
    '10.1109/IV51971.2022.9827374': {'problem': 'End to End', 'algorithm': 'SAC'},
    '10.1049/itr2.12336': {'problem': 'End to End', 'algorithm': 'DDPG'},
    '10.1007/978-981-99-8018-5_16': {'problem': 'End to End', 'algorithm': 'Actor Critic'},
    '10.1109/TCYB.2022.3163816': {'problem': 'End to End', 'algorithm': 'Model-based DRL'}

    }
len(paper_method_domain_info)
# Out:
# 41

# %%
from collections import defaultdict

# Assuming 'paper_method_domain_info' is a dictionary with paper info
# paper_method_domain_info = { ... }

# Initialize a dictionary to hold the count of methods per problem
problem_method_count = defaultdict(lambda: defaultdict(int))

# Iterate through each paper's information
for paper_id, paper_info in paper_method_domain_info.items():
    problem = paper_info['problem']
    # Handle cases where there may be more than one algorithm listed for a paper
    algorithms = paper_info['algorithm'] if isinstance(paper_info['algorithm'], list) else [paper_info['algorithm']]
    for algorithm in algorithms:
        problem_method_count[problem][algorithm] += 1

# Convert the defaultdict to a regular dict for display or further processing
problem_method_count = {problem: dict(methods) for problem, methods in problem_method_count.items()}

problem_method_count
# Out:
# {'Path Planning': {'SAC': 3,
#   'PPO': 3,
#   'TD3': 4,
#   'DQN': 4,
#   'DDPG': 5,
#   'Actor Critic': 1},
#  'Lateral Control': {'DDPG': 3,
#   'DQN': 1,
#   'Actor Critic': 2,
#   'PPO': 1,
#   'PG': 1},
#  'Longitudinal Control': {'DDPG': 2, 'Model-based DRL': 1, 'ADP': 1},
#  'Longitudinal and Lateral Control': {'Model-based DRL': 1,
#   'PG': 1,
#   'DDPG': 1},
#  'End to End': {'Actor Critic': 2,
#   'PG': 1,
#   'SAC': 1,
#   'DDPG': 1,
#   'Model-based DRL': 1}}
